# %% [markdown]
# # 文字情感分析服務操作

# %%
from azure.core.credentials import AzureKeyCredential
from azure.ai.textanalytics import TextAnalyticsClient


key = "94a15ae6fe8946efa56a851eefb7a1c8"
endpoint = "https://tfb103azure.cognitiveservices.azure.com/"

text_analytics_client = TextAnalyticsClient(endpoint=endpoint, credential=AzureKeyCredential(key))
documents = [
    "I had the best day of my life.",
    "This was a waste of my time. The speaker put me to sleep.",
    "No tengo dinero ni nada que dar..."
]

result = text_analytics_client.analyze_sentiment(documents)
docs = [doc for doc in result if not doc.is_error]

for idx, doc in enumerate(docs):
    print("Document text: {}".format(documents[idx]))
    print("Overall sentiment: {}".format(doc.sentiment))
# Out:
# Document text: I had the best day of my life.
# Overall sentiment: positive
# Document text: This was a waste of my time. The speaker put me to sleep.
# Overall sentiment: negative
# Document text: No tengo dinero ni nada que dar...
# Overall sentiment: negative

# %% [markdown]
# # 文字語言偵測服務操作

# %%
from azure.core.credentials import AzureKeyCredential
from azure.ai.textanalytics import TextAnalyticsClient


key = "4af117272f99498e9cbca027398ead7a"
endpoint = "https://tfb103text.cognitiveservices.azure.com/"


text_analytics_client = TextAnalyticsClient(endpoint=endpoint, credential=AzureKeyCredential(key))
documents = [
    "This document is written in English.",
    "Este es un document escrito en Español.",
    "这是一个用中文写的文件",
    "這是一個用中文寫的文件",
    "これは日本語で書かれた文書です",
    "Dies ist ein Dokument in deutsche Sprache.",
    "Detta är ett dokument skrivet på engelska."
]

result = text_analytics_client.detect_language(documents)

for idx, doc in enumerate(result):
    if not doc.is_error:
        print("Document text: {}".format(documents[idx]))
        print("Language detected: {}".format(doc.primary_language.name))
        print("ISO6391 name: {}".format(doc.primary_language.iso6391_name))
        print("Confidence score: {}\n".format(doc.primary_language.confidence_score))
    if doc.is_error:
        print(doc.id, doc.error)
# Out:
# ---------------------------------------------------------------------------
# ServiceRequestError                       Traceback (most recent call last)
# <ipython-input-2-09bfb133ad6f> in <module>
#      18 ]
#      19
# ---> 20 result = text_analytics_client.detect_language(documents)
#      21
#      22 for idx, doc in enumerate(result):
#
# ~\anaconda3\envs\python_azure\lib\site-packages\azure\core\tracing\decorator.py in wrapper_use_tracer(*args, **kwargs)
#      81             span_impl_type = settings.tracing_implementation()
#      82             if span_impl_type is None:
# ---> 83                 return func(*args, **kwargs)
#      84
#      85             # Merge span is parameter is set, but only if no explicit parent are passed
#
# ~\anaconda3\envs\python_azure\lib\site-packages\azure\ai\textanalytics\_text_analytics_client.py in detect_language(self, documents, **kwargs)
#     195             kwargs["logging_opt_out"] = disable_service_logs
#     196         try:
# --> 197             return self._client.languages(
#     198                 documents=docs,
#     199                 model_version=model_version,
#
# ~\anaconda3\envs\python_azure\lib\site-packages\azure\ai\textanalytics\_generated\_operations_mixin.py in languages(self, documents, model_version, show_stats, logging_opt_out, **kwargs)
#     522             return mixin_instance.languages(documents, model_version, show_stats, **kwargs)
#     523         elif api_version == 'v3.1':
# --> 524             return mixin_instance.languages(documents, model_version, show_stats, logging_opt_out, **kwargs)
#     525
#     526     def sentiment(
#
# ~\anaconda3\envs\python_azure\lib\site-packages\azure\ai\textanalytics\_generated\v3_1\operations\_text_analytics_client_operations.py in languages(self, documents, model_version, show_stats, logging_opt_out, **kwargs)
#    1014         body_content_kwargs['content'] = body_content
#    1015         request = self._client.post(url, query_parameters, header_parameters, **body_content_kwargs)
# -> 1016         pipeline_response = self._client._pipeline.run(request, stream=False, **kwargs)
#    1017         response = pipeline_response.http_response
#    1018
#
# ~\anaconda3\envs\python_azure\lib\site-packages\azure\core\pipeline\_base.py in run(self, request, **kwargs)
#     209             else _TransportRunner(self._transport)
#     210         )
# --> 211         return first_node.send(pipeline_request)  # type: ignore
#
# ~\anaconda3\envs\python_azure\lib\site-packages\azure\core\pipeline\_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# ~\anaconda3\envs\python_azure\lib\site-packages\azure\core\pipeline\_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# ~\anaconda3\envs\python_azure\lib\site-packages\azure\core\pipeline\_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# ~\anaconda3\envs\python_azure\lib\site-packages\azure\core\pipeline\_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# ~\anaconda3\envs\python_azure\lib\site-packages\azure\core\pipeline\_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# ~\anaconda3\envs\python_azure\lib\site-packages\azure\core\pipeline\policies\_redirect.py in send(self, request)
#     156         redirect_settings = self.configure_redirects(request.context.options)
#     157         while retryable:
# --> 158             response = self.next.send(request)
#     159             redirect_location = self.get_redirect_location(response)
#     160             if redirect_location and redirect_settings['allow']:
#
# ~\anaconda3\envs\python_azure\lib\site-packages\azure\core\pipeline\policies\_retry.py in send(self, request)
#     465                             is_response_error = True
#     466                         continue
# --> 467                 raise err
#     468             finally:
#     469                 end_time = time.time()
#
# ~\anaconda3\envs\python_azure\lib\site-packages\azure\core\pipeline\policies\_retry.py in send(self, request)
#     443                 start_time = time.time()
#     444                 self._configure_timeout(request, absolute_timeout, is_response_error)
# --> 445                 response = self.next.send(request)
#     446                 if self.is_retry(retry_settings, response):
#     447                     retry_active = self.increment(retry_settings, response=response)
#
# ~\anaconda3\envs\python_azure\lib\site-packages\azure\core\pipeline\_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# ~\anaconda3\envs\python_azure\lib\site-packages\azure\core\pipeline\_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# ~\anaconda3\envs\python_azure\lib\site-packages\azure\core\pipeline\_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# ~\anaconda3\envs\python_azure\lib\site-packages\azure\core\pipeline\_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# ~\anaconda3\envs\python_azure\lib\site-packages\azure\core\pipeline\_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# ~\anaconda3\envs\python_azure\lib\site-packages\azure\core\pipeline\_base.py in send(self, request)
#     101         return PipelineResponse(
#     102             request.http_request,
# --> 103             self._sender.send(request.http_request, **request.context.options),
#     104             context=request.context,
#     105         )
#
# ~\anaconda3\envs\python_azure\lib\site-packages\azure\core\pipeline\transport\_requests_basic.py in send(self, request, **kwargs)
#     296
#     297         if error:
# --> 298             raise error
#     299         return RequestsTransportResponse(request, response, self.connection_config.data_block_size)
#
# ServiceRequestError: <urllib3.connection.HTTPSConnection object at 0x000001BE6FED4CD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
